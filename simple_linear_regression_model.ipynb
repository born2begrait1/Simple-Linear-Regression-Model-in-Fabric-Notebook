# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 4, Finished, Available)

# %%
df = pd.read_parquet("abfss://b67a4b8d-a01e-4a4e-925f-d922133adb48@onelake.dfs.fabric.microsoft.com/1c9bba50-92b9-4222-a438-1ed171369403/Tables/salary_data_for_simple_linear_regression_model")
display(df.head(5))
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 5, Finished, Available)
# SynapseWidget(Synapse.DataFrame, a52bcb86-bc04-48f9-9b85-917e4eb358c0)

# %%
df.describe()
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 6, Finished, Available)
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.scatter(df['YearsExperience'], df['Salary'])
plt.title('Scatter Plot')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 7, Finished, Available)
# Text(0, 0.5, 'Salary')

# %%
# Histogram
plt.subplot(1, 3, 3)
plt.hist(df['Salary'], bins=10, color='skyblue', edgecolor='black')
plt.title('Salary Histogram')
plt.xlabel('Salary')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 9, Finished, Available)

# %%
# Splitting Variable into Dependent and Independent Variable
X = df.iloc[:, :1]  
y = df.iloc[:, 1:]
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 10, Finished, Available)

# %%
# Splitting dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 11, Finished, Available)

# %%
# Initialization of the Regressor model instance 
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 12, Finished, Available)
# 2024-01-11:01:51:10,492 WARNING  [tracking_store.py:153] log_inputs not supported
# LinearRegression()

# %%
# Prediction result   
y_pred_train = regressor.predict(X_train)
y_pred_test = regressor.predict(X_test)
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 13, Finished, Available)
# 2024-01-11:01:51:28,434 WARNING  [tracking_store.py:153] log_inputs not supported
# 2024-01-11:01:51:28,457 WARNING  [tracking_store.py:153] log_inputs not supported

# %%
# Prediction on training set
plt.scatter(X_train, y_train, color = 'skyblue')
plt.plot(X_train, y_pred_train, color = 'darkorange')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 14, Finished, Available)

# %%
# Prediction on the test set
plt.scatter(X_test, y_test, color = 'skyblue')
plt.plot(X_train, y_pred_train, color = 'darkorange')
plt.title('Salary vs Experience (Test Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 15, Finished, Available)

# %%
# Regressor coefficients and intercept
print(f'Coefficient: {regressor.coef_}')
print(f'Intercept: {regressor.intercept_}')
# Out:
# StatementMeta(, b88d8bbc-1e72-4244-b3b7-f876f54c4498, 16, Finished, Available)
# Coefficient: [[9312.57512673]]
# Intercept: [26780.09915063]
